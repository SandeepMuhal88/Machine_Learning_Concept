# %%
# %pip install kneed
# %pip install kneed[plot]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Input Data
# The DataGenerator class is only included as a utility to generate sample datasets.
#
# Note: x and y must be equal length arrays.

# %%
from kneed import KneeLocator, DataGenerator
x,y=DataGenerator.figure2()
print([round(i, 3) for i in x])
print([round(i, 3) for i in y])
plt.plot(x, y)
# Out:
# [np.float64(0.0), np.float64(0.111), np.float64(0.222), np.float64(0.333), np.float64(0.444), np.float64(0.556), np.float64(0.667), np.float64(0.778), np.float64(0.889), np.float64(1.0)]
# [np.float64(-5.0), np.float64(0.263), np.float64(1.897), np.float64(2.692), np.float64(3.163), np.float64(3.475), np.float64(3.696), np.float64(3.861), np.float64(3.989), np.float64(4.091)]

# %%
kneedle=KneeLocator(x, y, curve='convex', direction='increasing')
kneedle.plot_knee_normalized()

# %%
# Raw data and knee.
kneedle.plot_knee()

# %%
kneedle.elbow
# Out:
# np.float64(1.0)
