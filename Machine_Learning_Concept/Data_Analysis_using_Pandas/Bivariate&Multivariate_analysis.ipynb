# %% [markdown]
# IMPORT DATA SETS

# %%
# %pip install numpy 
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
Titanic=pd.read_csv('Train.csv')
Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
flight=sns.load_dataset('flights')
# flight.head()
flight.sample(5)
# Out:
#      year month  passengers
# 104  1957   Sep         404
# 80   1955   Sep         312
# 109  1958   Feb         318
# 33   1951   Oct         162
# 94   1956   Nov         271

# %%
iris=sns.load_dataset('iris')
# iris.head()
iris.sample(6)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 20            5.4          3.4           1.7          0.2      setosa
# 54            6.5          2.8           4.6          1.5  versicolor
# 127           6.1          3.0           4.9          1.8   virginica
# 98            5.1          2.5           3.0          1.1  versicolor
# 73            6.1          2.8           4.7          1.2  versicolor
# 96            5.7          2.9           4.2          1.3  versicolor

# %% [markdown]
# ### 1. Scatterplot (Numerical - Numerical)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Bivariate
# Use Tips Datasets
sns.scatterplot(data=df,x='total_bill',y='tip',color='black')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='smoker')
plt.show()

# %%
# Multivariate
sns.scatterplot(data=df,x='total_bill',y='tip',hue='sex',style='smoker',size='size')
plt.show()

# %% [markdown]
# ### 2. Bar Plot (Numerical - Categorical)

# %%
# Use Titanic Datasets
Titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Example using the 'tips' dataset (df)
sns.barplot(data=df, x='sex', y='total_bill')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# multivariate example using the tips dataset
sns.barplot(data=df, x='sex', y='total_bill', hue='smoker', palette='viridis')
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=df,x="day",y="total_bill",hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(data=Titanic,x='Pclass',y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
# Multivariate
sns.boxplot(data=Titanic,x='Pclass',hue='Survived',y='Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# ### 4. Distplot (Numerical - Categorical)

# %%
sns.kdeplot(Titanic[Titanic['Survived']==0]['Age'])
sns.kdeplot(Titanic[Titanic['Survived']==1]['Age'])
# sns.distplot()
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# Heatmap(Categorical to Categorical) Analysis

# %%
sns.heatmap(pd.crosstab(Titanic['Pclass'],Titanic['Survived'],margins=True))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
(Titanic.groupby('Embarked')['Survived'].mean() * 100)
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %% [markdown]
# ClusterMap (Categorical to Categorical) Analysis

# %%
pd.crosstab(Titanic['SibSp'], Titanic['Survived'], normalize='index')
# Out:
# Survived         0         1
# SibSp
# 0         0.654605  0.345395
# 1         0.464115  0.535885
# 2         0.535714  0.464286
# 3         0.750000  0.250000
# 4         0.833333  0.166667
# 5         1.000000  0.000000
# 8         1.000000  0.000000

# %%
sns.clustermap(pd.crosstab(Titanic['SibSp'], Titanic['Survived'], normalize='index'))

# %% [markdown]
# ## Pair plot

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(Titanic,hue='Survived')

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# LinePlot Numerical to Numerical data analysis

# %%
flight.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flight.groupby('year').agg({'passengers':'sum'}).plot(kind='bar')
# Out:
# <Axes: xlabel='year'>
